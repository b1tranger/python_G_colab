# %% [markdown]
# <a href="https://colab.research.google.com/github/b1tranger/python_G_colab/blob/main/Day%205/b1tranger/%5BCodeForces%5D_Sheet_1_Assiut_University_Training_Newcomers_%5BD5%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Problem Set: https://codeforces.com/group/MWSDmqGsZm/contest/219774

# %% [markdown]
# Problem: [Z. Binary Search](https://codeforces.com/group/MWSDmqGsZm/contest/219774/problem/Z)
#
# Solution:

# %% [markdown]
# # # approach 1

# %%
#  Time limit exceeded on test 2
#################################

n = input() # size, test case
a = n.split()
size = int(a[0])
run = int(a[1])
str_arr = input()
arr = str_arr.split() # input regardless of "size" value
for j in range(run):
  target = input()
  flag = 0
  for i in range(size):
    if (arr[i]==target):
      flag = 1
      # print("found")
    # else:
      # print("not found")
  if (flag==1):
    print("found")
  else:
    print("not found")
# Out:
# 5 3
# 1 5 4 3 2
# 5
# found
# 3
# found
# 6
# not found

# %% [markdown]
# ---
#
# # # approach 2

# %%
def binSearch(arr,size,target):
    low = 0
    high = size-1
    while low <=high:
     mid = low + (high-low)//2 # Changed / to // for integer division
     if(arr[mid]==target):
      return 1
     elif(arr[mid]<target):
      low = mid+1
     else:
      high = mid-1
    # return 0

n = input() # size, test case
a = n.split()
size = int(a[0])
run = int(a[1])
str_arr = input()
# Convert elements of arr to integers
arr = [int(x) for x in str_arr.split()] # Fixed: Convert list elements to int
arr.sort() # forgot to sort for binary search
for j in range(run):
    target = input()
    target = int(target)
    flag = 0
    flag = binSearch(arr,size,target)
    if (flag==1):
      print("found")
    else:
      print("not found")
# Out:
# 5 3
# 1 5 4 3 2
# 5
# found
# 3
# found
# 0
# not found

# %% [markdown]
# ### 1. `list.sort()` Method
#
# This method sorts the list **in-place**, meaning it modifies the original list and does not return a new list. It returns `None`.

# %%
# Example with list.sort()
my_list = [3, 1, 4, 1, 5, 9, 2, 6]
print(f"Original list: {my_list}")

my_list.sort()
print(f"Sorted list (in-place): {my_list}")

# You can also sort in descending order
my_list_desc = [3, 1, 4, 1, 5, 9, 2, 6]
my_list_desc.sort(reverse=True)
print(f"Sorted list (descending): {my_list_desc}")

# Sorting a list of strings
words = ["banana", "apple", "cherry", "date"]
words.sort()
print(f"Sorted words: {words}")

# %% [markdown]
# ### 2. `sorted()` Function
#
# This is a built-in function that takes an iterable (like a list, tuple, string, etc.) and returns a **new sorted list**. It does not modify the original iterable.

# %%
# Example with sorted()
another_list = [8, 0, 7, 1, 2, 3]
print(f"Original list: {another_list}")

sorted_new_list = sorted(another_list)
print(f"New sorted list: {sorted_new_list}")
print(f"Original list after sorted(): {another_list}") # Original list is unchanged

# Sorting in descending order
sorted_desc = sorted(another_list, reverse=True)
print(f"New sorted list (descending): {sorted_desc}")

# Sorting a tuple
my_tuple = (5, 2, 8, 1)
sorted_tuple = sorted(my_tuple)
print(f"Sorted tuple (as a list): {sorted_tuple}")

# %% [markdown]
# ### Key Differences:
#
# *   **`list.sort()`**: Works only on lists, modifies the list in place, returns `None`.
# *   **`sorted()`**: Works on any iterable (lists, tuples, strings, dictionaries, etc.), always returns a new list, leaves the original iterable unchanged.
#
# Both methods support an optional `key` argument for custom sorting (e.g., sorting by length of strings, or by a specific element in a list of tuples) and a `reverse` argument for descending order.

# %%
# Define a function
def greet(name):
  """This function greets the person passed in as a parameter."""
  print(f"Hello, {name}!")

# Call the function
greet("Alice")

# You can also define functions with multiple parameters and return values
def add_numbers(a, b):
  """This function takes two numbers and returns their sum."""
  return a + b

# Call the function and store the result
result = add_numbers(5, 3)
print(f"The sum is: {result}")
# Out:
# Hello, Alice!
# The sum is: 8

# %%
# Define a function that takes a list as an argument
def process_list(my_list):
  print("Inside the function:")
  print(f"Original list: {my_list}")

  # You can iterate through the list
  print("Elements:")
  for item in my_list:
    print(item)

  # You can modify the list (if mutable)
  # For example, adding an element
  my_list.append("new_item")
  print(f"List after modification: {my_list}")
  print("-" * 20)

# Declare some lists (arrays)
my_numbers = [1, 2, 3, 4, 5]
my_strings = ["apple", "banana", "cherry"]

# Call the function, passing the lists
print("Calling process_list with my_numbers:")
process_list(my_numbers)

print("Calling process_list with my_strings:")
process_list(my_strings)

# Observe that my_numbers was modified by the function (lists are mutable)
print(f"my_numbers after function calls: {my_numbers}")
# Out:
# Calling process_list with my_numbers:
# Inside the function:
# Original list: [1, 2, 3, 4, 5]
# Elements:
# 1
# 2
# 3
# 4
# 5
# List after modification: [1, 2, 3, 4, 5, 'new_item']
# --------------------
# Calling process_list with my_strings:
# Inside the function:
# Original list: ['apple', 'banana', 'cherry']
# Elements:
# apple
# banana
# cherry
# List after modification: ['apple', 'banana', 'cherry', 'new_item']
# --------------------
# my_numbers after function calls: [1, 2, 3, 4, 5, 'new_item']

# %% [markdown]
# ### Explanation:
#
# 1.  **Function Definition**: The function `process_list(my_list)` is defined, specifying `my_list` as its parameter. When you call this function, whatever list you pass to it will be referred to as `my_list` inside the function.
# 2.  **Passing by Reference (Implicitly)**: In Python, when you pass a mutable object like a list to a function, you are essentially passing a reference to that object. This means that if you modify the list *inside* the function (e.g., using `append()`, `remove()`, etc.), those changes will be reflected in the original list outside the function. This is demonstrated by the `my_numbers` list being modified after `process_list` is called.

# %% [markdown]
# ---
#
# # # approach 3

# %%
def binSearch(arr,size,target):
    low = 0
    high = size-1
    while low <=high:
     mid = low + (high-low)//2 # Changed / to // for integer division
     if(arr[mid]==target):
      return 1
     elif(arr[mid]<target):
      low = mid+1
     else:
      high = mid-1
    # return 0

n = input() # size, test case
a = n.split()
size = int(a[0])
run = int(a[1])
# str_arr = input()
arr = []
for i in range(size): # cannot take input in single line like "1 5 4 3 2"
  x = int(input())
  arr.append(x)

# Convert elements of arr to integers
# arr = [int(x) for x in str_arr.split()] # Fixed: Convert list elements to int
arr.sort() # forgot to sort for binary search
for j in range(run):
    target = input()
    target = int(target)
    flag = 0
    flag = binSearch(arr,size,target)
    if (flag==1):
      print("found")
    else:
      print("not found")
# Out:
# 5 3
# 1
# 5
# 4
# 3
# 2
# 1
# found
# 4
# found
# 6
# not found

# %% [markdown]
# You can achieve something similar to C++'s fixed-size array input in Python, though Python lists are dynamically sized. Here are two common ways to handle looped input to create a list of a predetermined or implied size:
#
# ### Method 1: Reading the size `N`, then `N` individual elements
#
# This method is closer to how you might pre-declare an array size in C++ and then fill it element by element in a loop. In Python, you'd typically initialize an empty list or a list of a specific size with placeholder values, and then populate it.

# %%
# Read the desired size of the list
list_size = int(input("Enter the number of elements: "))

# Initialize an empty list
my_list = []

# Loop to take individual elements as input
print(f"Enter {list_size} elements, one by one:")
for i in range(list_size):
    element = input(f"Element {i+1}: ")
    my_list.append(element)

print(f"Your list (string elements): {my_list}")

# If you need integer elements, you can convert them during input:
# my_int_list = []
# for i in range(list_size):
#     element = int(input(f"Element {i+1} (integer): "))
#     my_int_list.append(element)
# print(f"Your list (integer elements): {my_int_list}")

# %% [markdown]
# ### Method 2: Reading all elements on a single line
#
# This is often more convenient in competitive programming. You read a single line of space-separated values and then use the `split()` method to create a list of strings. You can then convert these strings to integers if needed.

# %%
# Read a single line of space-separated numbers
input_line = input("Enter elements separated by spaces: ")

# Split the line into a list of strings
string_list = input_line.split()

print(f"Your list (string elements): {string_list}")

# To convert to a list of integers:
# int_list = [int(x) for x in string_list]
# print(f"Your list (integer elements): {int_list}")

# Note: The cell 'ol3NhUdGPgBX' in your notebook already uses this method:
# n = input()
# a = n.split()
# size = len(a)

# %% [markdown]
# <br><br><br><br><br><br><br>

# %% [markdown]
# Problem: [Y. Range sum query](https://codeforces.com/group/MWSDmqGsZm/contest/219774/problem/Y)
#
# Solution:

# %% [markdown]
# # # approach 1

# %%
n = input()
temp = n.split()
# print(str_arr)
size = int(temp[0])
run = int(temp[1]) # test cases
str_arr = input()
arr = [int(x) for x in str_arr.split()]
for i in range(run):
  temp = input()
  temp = temp.split()
  l = int(temp[0])
  R - int(temp[1])
# Out:
# 1 2 3
# ['1', '2', '3']
