# %% [markdown]
# Problem Set: [Hello 2026](https://codeforces.com/contest/2183/)

# %% [markdown]
# Problem: [A. Binary Array Game](https://codeforces.com/contest/2183/problem/A)
#
# Solution:

# %%
t = input()
for i in range(t):
  n = input()
  for j in range(n)

# %%
# Declaring an empty list (array)
my_list = []
print("Empty list declared:", my_list)

# Inputting values into the list
num_elements = int(input("How many elements do you want to add to the list? "))

print("Enter the elements one by one:")
for i in range(num_elements):
    value = input(f"Enter element {i+1}: ")
    my_list.append(value) # Add the input value to the list

print("List after inputting values:", my_list)

# If you want to store numbers, you should convert the input:
# my_numeric_list = []
# num_numeric_elements = int(input("How many numeric elements? "))
# for i in range(num_numeric_elements):
#     num_value = int(input(f"Enter numeric element {i+1}: ")) # Convert to int
#     my_numeric_list.append(num_value)
# print("Numeric list:", my_numeric_list)
# Out:
# Empty list declared: []
# How many elements do you want to add to the list? 5
# Enter the elements one by one:
# Enter element 1: 2
# Enter element 2: 4
# Enter element 3: 5
# Enter element 4: 6
# Enter element 5: 1
# List after inputting values: ['2', '4', '5', '6', '1']
